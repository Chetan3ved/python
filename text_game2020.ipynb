# %%
"""Feed the bad """
"""Bribe the rule"""

""" #DocString:
    #The Story of the game is to bribe the govt system
    #to get the toxic out of your factory.
    #first step is to bribe the local cops and continuous perks costs $250,000
    #second bribe the local minister costs $300,000
    #third bribe the industrial minister costs $ 1M
    #fourth bribe the environment minister costs $ 1M
    #Release the toxic in to the environment.
    
"""



from sys import exit
import random

def start () :
    print("""My factory is meant to make profits for me and my nation but if i put people 
    and environment in my mind i cant make profit eventhough i spend lot of money 
    on bribery that is just 0.1% if i obey the rules i have to lose 100times more than that""")
          
    input ("<Press enter and continue>\n")
    
    starting_path()
    
def starting_path() :
    
    print("""So for now i will listen to my greediness , to stay wealthy and powerful i decide let bribe. 
    1. Throw some money and watch the circus. 
    2. I love my nature more than money
    3. I can't take any decision i am confused
    """)
    
    choice = input ("> \n")
    
    if "1" in choice or Throw in choice or circus in choice:
        print("\n Begin the battle \n")
        input("Press enter to continue\n")
        cop()
        
    elif "2" in choice or love in choice or money in choice:
        print("Love is wealth i am not materialistic \n")
        input("Press enter to continue\n")
        fail()
                    
    elif "3" in choice or decision in choice or circus in choice:
        print("\n Good luck, dont be lost")
        input("Press enter to continue\n") 
        fail(0)
            
    else:
        print("Invalid command. Please try again.")
        input("<Press enter to continue>\n")
        starting_path()
        
def cop() :
    print("""You had a chat with like minded greedy commissioner of police, in return your way you came
    to know he's is having enemies in his own work place so you have to play nice that may back fire on you,
    so you decied take another shit job to calm his enemies this whole package come with hefty amount 
    $250000 yearly""")
    
    
    requirement_list = ['Do you really want to do this',
                        'Gifts in the shape of luxury vacation?',
                        'Gifts in the shape of material things or property?',
                        'Gifts in the shape of paying off their kids expensive schooling fees?']
    
    #requirements = 3
    
    #for requirement in requirement_list:
    #requirement = random.choice(requirement_list)
    
    userValue = eval(input("Enter any number?"))
    print(requirement_list[userValue])
    
    if userValue >3:
        print("Invalid command. Please try again.")
        input("<Press enter to continue>\n")
        cop()    
        
    if requirement_list[userValue] == requirement_list[0]:
        print("You can input anything and you're ok.")
        name = input("Your name: \n")
        
        #requirements -=1  
       
     
    if requirement_list[userValue]  == requirement_list[1]:
        print("1) yes, only once in two years is agreeable")
        print("2) you cops are so cheap, bye bye")

        cheap = input("> \n")

        if '1' in cheap or "yes" in cheap or "agreeable" in cheap:
            print("this just beginning sir\n")
            print("You made it across the local cops \n")
            mission_minister()
          

        elif '2' in cheap or "cops" in cheap or "bye" in cheap:
            print("so cheap")
            fail()
        return

    if requirement_list[userValue]  == requirement_list[2]:
        print("1) Deal is doable")
        print("2) cant do the deal")

        req = input("> \n")

        if '1' in req or Deal in req or doable in cheap:
            print("great choice you made for destruction\n")
            input("<Press enter to continue>\n")
            print("You made it across the local cops \n")
            mission_minister()


        elif '2' in req or cant in req or deal in cheap:
            print("ok ok no prob")
            fail()
        return
            

    if requirement_list[userValue]  == requirement_list[3]:
        print("1) we will take care of education expense")
        print("2) i have no interested")

        answer = input("> \n")

        if answer == "1":
            print("haha you have no way around just agree")
            print("You made it across the local cops \n")
            mission_minister()

        else:
            print("oh shit, you may better take cash or fuck off")
            fail()
        return
    
 
       
        
  
    
def mission_minister():
    
    print("""So far we just made a little move, the real money game and cruelty just about to start""")
    print("""Local minister came to know the deal you made with local cops, so he just wants $ 50,000 
    more than the previous investment""")
    print("1) Agree, i can do that")
    print("2) This is not gonna stop here, i am done")
    
    mission = input(" > \n")
    
    if '1' in mission or "Agree" in mission or "do" in mission:
        print("Great, we'll take care no onwards you dont worry")
        input("<Press enter to continue>\n")
        industrial_minister()
    else:
        print("Your term is coming to end, so i dont want to make any deal here")
        cop()
        
def industrial_minister():
    print("""It is very challenging when it come to state or central level it doesn't mean i can't do,
    i have strong opposition here but i also have friends in opposition party but if this want you want 
    i have to zip many people mouths and you know how is that possible""")
    print("1) Industries are back bone to country, All good")
    print("2) This is what i can't sorry")
    
    industrial = input(" > \n")
    
    if '1' in industrial or "bone" in industrial or "country" in industrial:
        print("Deal is done with $ 1M")
        input("<Press enter to continue>\n")
        environmental_minister()
    
    elif '2' in industrial or "what" in industrial or "sorry" in industrial:
        print("Seems like doing business with you is on the verge of knife, good bye")
        cop()
        
def environmental_minister():
    print
    ("""I clear all the path for you, you dont have to do anything, i already managed other floks. 
    so hope you know what i am taking with you if you agree and help in this process we will be business
    partners""")
    print("Great, you will get $1M in bonds with shares in my company")
    input("<Press enter to continue>\n")
    exit(0)
    
def fail():
    print("""Thanks for coming all the way here with bringing friends with you
          now its not that tough to seal your factory and kick your friends in the jail""")
    input('you game is over')
    exit(0)

start()
# Out:
# My factory is meant to make profits for me and my nation but if i put people
#     and environment in my mind i cant make profit eventhough i spend lot of money
#     on bribery that is just 0.1% if i obey the rules i have to lose 100times more than that
# <Press enter and continue>
#
# So for now i will listen to my greediness , to stay wealthy and powerful i decide let bribe.
#     1. Throw some money and watch the circus.
#     2. I love my nature more than money
#     3. I can't take any decision i am confused
#
# >
# 1
#
#  Begin the battle
#
# Press enter to continue
# 44
# You had a chat with like minded greedy commissioner of police, in return your way you came
#     to know he's is having enemies in his own work place so you have to play nice that may back fire on you,
#     so you decied take another shit job to calm his enemies this whole package come with hefty amount
#     $250000 yearly
# Enter any number?44
# ...
